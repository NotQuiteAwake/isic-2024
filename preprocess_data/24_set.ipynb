# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd

import matplotlib.pyplot as plt
import numpy as np

import isic
from isic import printenc, println, printdash

SEED = 6

# %%
# import datasets and metadata
ds24 = isic.get_2024() # dataset
md24 = ds24.get_proc_metadata() # metadata

ds_comp = isic.get_complete()
md_comp = ds_comp.get_proc_metadata()

# %%
# split out this cell because it's time consuming
printenc("Check dataset integrity",
         "isic_24", len(ds24.find_missing()) == 0,
         "isic archive (complete)", len(ds_comp.find_missing()) == 0)

# gettting rid of mixed type
# print(md24.iloc[:, 51])
# print(md24.iloc[:, 51].value_counts(dropna = False))
# Out:
# 100%|███████████████████████████████████████████████| 401059/401059 [00:25<00:00, 15894.44it/s]
# 100%|█████████████████████████████████████████████████| 81722/81722 [00:01<00:00, 54225.61it/s]
# --------------------
# Check dataset integrity
# isic_24
# True
# isic archive (complete)
# True
# --------------------

# %%
printenc("Compare columns in datasets")

col_24 = set(md24.columns.values)
col_comp = set(md_comp.columns.values)

col_unique_24 = col_24 - col_comp
col_unique_comp = col_comp - col_24
col_shared = col_comp & col_24

printenc("Columns unique to 2024 set",
         sorted(col_unique_24))

printenc("Columns unique to isic archive",
         sorted(col_unique_comp))

printenc("Shared columns",
         sorted(col_shared))
# Out:
# --------------------
# Compare columns in datasets
# --------------------
# --------------------
# Columns unique to 2024 set
# ['iddx_1', 'iddx_2', 'iddx_3', 'iddx_4', 'iddx_5', 'iddx_full', 'target', 'tbp_lv_A', 'tbp_lv_Aext', 'tbp_lv_B', 'tbp_lv_Bext', 'tbp_lv_C', 'tbp_lv_Cext', 'tbp_lv_H', 'tbp_lv_Hext', 'tbp_lv_L', 'tbp_lv_Lext', 'tbp_lv_areaMM2', 'tbp_lv_area_perim_ratio', 'tbp_lv_color_std_mean', 'tbp_lv_deltaA', 'tbp_lv_deltaB', 'tbp_lv_deltaL', 'tbp_lv_deltaLB', 'tbp_lv_deltaLBnorm', 'tbp_lv_dnn_lesion_confidence', 'tbp_lv_eccentricity', 'tbp_lv_location', 'tbp_lv_location_simple', 'tbp_lv_minorAxisMM', 'tbp_lv_nevi_confidence', 'tbp_lv_norm_border', 'tbp_lv_norm_color', 'tbp_lv_perimeterMM', 'tbp_lv_radial_color_std_max', 'tbp_lv_stdL', 'tbp_lv_stdLExt', 'tbp_lv_symm_2axis', 'tbp_lv_symm_2axis_angle', 'tbp_lv_x', 'tbp_lv_y', 'tbp_lv_z', 'tbp_tile_type']
# --------------------
# --------------------
# Columns unique to isic archive
# ['acquisition_day', 'benign_malignant', 'concomitant_biopsy', 'dermoscopic_type', 'diagnosis', 'diagnosis_confirm_type', 'family_hx_mm', 'fitzpatrick_skin_type', 'mel_class', 'mel_type', 'mel_ulcer', 'melanocytic', 'nevus_type', 'personal_hx_mm', 'pixels_x', 'pixels_y']
# --------------------
# --------------------
# Shared columns
# ['PROC_source', 'PROC_use', 'age_approx', 'anatom_site_general', 'attribution', 'clin_size_long_diam_mm', 'copyright_license', 'image_type', 'isic_id', 'lesion_id', 'mel_mitotic_index', 'mel_thick_mm', 'patient_id', 'sex']
# --------------------

# %%
printenc(
"""\
Study columns unique to isic_24

https://www.kaggle.com/competitions/isic-2024-challenge/data

OBSERVATIONS

- iddx columns

These are unique to the input and it must be noted that except iddx_1 (=benign_malignant)
all the others take value NaN except for malignant samples. Unlikely to be very useful.
Also all those other tags have so few samples I doubt they can be generalisable (iddx_full)

IDDX_1 WILL BE MAPPED TO BENIGN_MALIGNANT. FIRST LETTER DOWNCASED.

IDDX_3 ROUGHLY MAPS TO DIAGNOSIS BUT HAS SIGHTLY DIFFERENT VALUES

- columns only present in test set

iddx columns for example are only present in the train set (because they give diagnosis!)
Only way I can think of using them is have the model predict them, but the sample size...

- target columns

Interestingly those samples that are labelled indeterminate are sorted into target 0 (benign)

COMPLETE SET INDETERMINATE SAMPLES WILL ALSO BE PROCESSED THUS, EXCEPT INDETERMINATE/MALIGNANT

- anatom_site_general

This column is shared between 2024 and complete sets. There are surprisingly some NA values for
TBP, but this cannot be resolved as one see that in the [tbp_lv_location] column there are equal
number of locations that are simply "unknown".

- Other columns

There are indeed many numerical metrics which are potentially be of some use:
a quick visial inspection suggests there are NO NAN'S IN MANY OF THESE COLUMNS.

However these are UNIQUE TO THE 2024 set and are products of the TBP procedure,
and so again suffers from the severe lack of positive samples. I would naively think
that a model would either learn to just ignore these parameters or somewhat overfit.\
""")

for col in sorted(col_unique_24):
    printenc(f"Statistics for column [{col}]",
             isic.dtype_based_stats(md24, col))
# Out:
# --------------------
# Study columns unique to isic_24
#
# https://www.kaggle.com/competitions/isic-2024-challenge/data
#
# OBSERVATIONS
#
# - iddx columns
#
# These are unique to the input and it must be noted that except iddx_1 (=benign_malignant)
# all the others take value NaN except for malignant samples. Unlikely to be very useful.
# Also all those other tags have so few samples I doubt they can be generalisable (iddx_full)
#
# IDDX_1 WILL BE MAPPED TO BENIGN_MALIGNANT. FIRST LETTER DOWNCASED.
#
# IDDX_3 ROUGHLY MAPS TO DIAGNOSIS BUT HAS SIGHTLY DIFFERENT VALUES
#
# - columns only present in test set
#
# iddx columns for example are only present in the train set (because they give diagnosis!)
# Only way I can think of using them is have the model predict them, but the sample size...
#
# - target columns
#
# Interestingly those samples that are labelled indeterminate are sorted into target 0 (benign)
#
# COMPLETE SET INDETERMINATE SAMPLES WILL ALSO BE PROCESSED THUS, EXCEPT INDETERMINATE/MALIGNANT
#
# - anatom_site_general
#
# This column is shared between 2024 and complete sets. There are surprisingly some NA values for
# TBP, but this cannot be resolved as one see that in the [tbp_lv_location] column there are equal
# number of locations that are simply "unknown".
#
# - Other columns
#
# There are indeed many numerical metrics which are potentially be of some use:
# a quick visial inspection suggests there are NO NAN'S IN MANY OF THESE COLUMNS.
#
# However these are UNIQUE TO THE 2024 set and are products of the TBP procedure,
# and so again suffers from the severe lack of positive samples. I would naively think
# that a model would either learn to just ignore these parameters or somewhat overfit.
# --------------------
# --------------------
# Statistics for column [iddx_1]
# iddx_1
# Benign           400552
# Malignant           393
# Indeterminate       114
# Name: count, dtype: int64
# --------------------
# --------------------
# Statistics for column [iddx_2]
# iddx_2
# NaN                                                               399991
# Benign melanocytic proliferations                                    443
# Malignant adnexal epithelial proliferations - Follicular             163
# Malignant melanocytic proliferations (Melanoma)                      157
# Benign epidermal proliferations                                       83
# Indeterminate melanocytic proliferations                              75
# Malignant epidermal proliferations                                    73
# Indeterminate epidermal proliferations                                39
# Benign soft tissue proliferations - Fibro-histiocytic                 15
# Inflammatory or infectious diseases                                    7
# Flat melanotic pigmentations - not melanocytic nevus                   5
# Benign soft tissue proliferations - Vascular                           3
# Cysts                                                                  2
# Benign adnexal epithelial proliferations - Follicular                  2
# Benign adnexal epithelial proliferations - Apocrine or Eccrine         1
# Name: count, dtype: int64
# --------------------
# --------------------
# Statistics for column [iddx_3]
# iddx_3
# NaN                                                   399994
# Nevus                                                    443
# Basal cell carcinoma                                     163
# Melanoma in situ                                          80
# Atypical melanocytic neoplasm                             64
# Melanoma Invasive                                         63
# Seborrheic keratosis                                      57
# Squamous cell carcinoma in situ                           49
# Solar or actinic keratosis                                39
# Squamous cell carcinoma, Invasive                         22
# Melanoma, NOS                                             13
# Solar lentigo                                             12
# Lichen planus like keratosis                              11
# Dermatofibroma                                            11
# Atypical intraepithelial melanocytic proliferation        11
# Verruca                                                    7
# Lentigo NOS                                                5
# Pigmented benign keratosis                                 3
# Hemangioma                                                 3
# Angiofibroma                                               2
# Squamous cell carcinoma, NOS                               2
# Trichilemmal or isthmic-catagen or pilar cyst              1
# Scar                                                       1
# Melanoma metastasis                                        1
# Hidradenoma                                                1
# Fibroepithelial polyp                                      1
# Name: count, dtype: int64
# --------------------
# --------------------
# Statistics for column [iddx_4]
# iddx_4
# NaN                                                                               400508
# Nevus, Atypical, Dysplastic, or Clark                                                228
# Basal cell carcinoma, Nodular                                                         98
# Basal cell carcinoma, Superficial                                                     48
# Melanoma Invasive, Superficial spreading                                              37
# Nevus, NOS, Compound                                                                  30
# Nevus, NOS, Dermal                                                                    20
# Melanoma in situ, Lentigo maligna type                                                12
# Melanoma in situ, associated with a nevus                                             12
# Nevus, NOS, Junctional                                                                10
# Melanoma in situ, Superficial spreading                                               10
# Melanoma Invasive, Associated with a nevus                                             7
# Basal cell carcinoma, Infiltrating                                                     6
# Squamous cell carcinoma, Invasive, Keratoacanthoma-type                                5
# Melanoma Invasive, On chronically sun-exposed skin or lentigo maligna melanoma         5
# Nevus, Congenital                                                                      4
# Hemangioma, Cherry                                                                     3
# Nevus, Spitz                                                                           3
# Nevus, Combined                                                                        2
# Angiofibroma, Facial                                                                   2
# Nevus, Of special anatomic site                                                        2
# Nevus, Deep penetrating                                                                2
# Blue nevus                                                                             1
# Squamous cell carcinoma in situ, Bowens disease                                        1
# Actinic keratosis, Bowenoid                                                            1
# Melanoma Invasive, Nodular                                                             1
# Seborrheic keratosis, Clonal                                                           1
# Name: count, dtype: int64
# --------------------
# --------------------
# Statistics for column [iddx_5]
# iddx_5
# <NA>                    401058
# Blue nevus, Cellular         1
# Name: count, dtype: Int64
# --------------------
# --------------------
# Statistics for column [iddx_full]
# iddx_full
# Benign                                                                                                                                                           399991
# Benign::Benign melanocytic proliferations::Nevus::Nevus, Atypical, Dysplastic, or Clark                                                                             228
# Benign::Benign melanocytic proliferations::Nevus                                                                                                                    141
# Malignant::Malignant adnexal epithelial proliferations - Follicular::Basal cell carcinoma::Basal cell carcinoma, Nodular                                             98
# Indeterminate::Indeterminate melanocytic proliferations::Atypical melanocytic neoplasm                                                                               64
# Benign::Benign epidermal proliferations::Seborrheic keratosis                                                                                                        56
# Malignant::Malignant adnexal epithelial proliferations - Follicular::Basal cell carcinoma::Basal cell carcinoma, Superficial                                         48
# Malignant::Malignant epidermal proliferations::Squamous cell carcinoma in situ                                                                                       48
# Malignant::Malignant melanocytic proliferations (Melanoma)::Melanoma in situ                                                                                         46
# Indeterminate::Indeterminate epidermal proliferations::Solar or actinic keratosis                                                                                    38
# Malignant::Malignant melanocytic proliferations (Melanoma)::Melanoma Invasive::Melanoma Invasive, Superficial spreading                                              37
# Benign::Benign melanocytic proliferations::Nevus::Nevus, NOS, Compound                                                                                               30
# Benign::Benign melanocytic proliferations::Nevus::Nevus, NOS, Dermal                                                                                                 20
# Malignant::Malignant epidermal proliferations::Squamous cell carcinoma, Invasive                                                                                     17
# Malignant::Malignant melanocytic proliferations (Melanoma)::Melanoma Invasive                                                                                        13
# Malignant::Malignant melanocytic proliferations (Melanoma)::Melanoma, NOS                                                                                            13
# Benign::Benign epidermal proliferations::Solar lentigo                                                                                                               12
# Malignant::Malignant melanocytic proliferations (Melanoma)::Melanoma in situ::Melanoma in situ, Lentigo maligna type                                                 12
# Malignant::Malignant melanocytic proliferations (Melanoma)::Melanoma in situ::Melanoma in situ, associated with a nevus                                              12
# Benign::Benign epidermal proliferations::Lichen planus like keratosis                                                                                                11
# Indeterminate::Indeterminate melanocytic proliferations::Atypical intraepithelial melanocytic proliferation                                                          11
# Benign::Benign soft tissue proliferations - Fibro-histiocytic::Dermatofibroma                                                                                        11
# Malignant::Malignant adnexal epithelial proliferations - Follicular::Basal cell carcinoma                                                                            11
# Malignant::Malignant melanocytic proliferations (Melanoma)::Melanoma in situ::Melanoma in situ, Superficial spreading                                                10
# Benign::Benign melanocytic proliferations::Nevus::Nevus, NOS, Junctional                                                                                             10
# Malignant::Malignant melanocytic proliferations (Melanoma)::Melanoma Invasive::Melanoma Invasive, Associated with a nevus                                             7
# Benign::Inflammatory or infectious diseases::Verruca                                                                                                                  7
# Malignant::Malignant adnexal epithelial proliferations - Follicular::Basal cell carcinoma::Basal cell carcinoma, Infiltrating                                         6
# Malignant::Malignant melanocytic proliferations (Melanoma)::Melanoma Invasive::Melanoma Invasive, On chronically sun-exposed skin or lentigo maligna melanoma         5
# Malignant::Malignant epidermal proliferations::Squamous cell carcinoma, Invasive::Squamous cell carcinoma, Invasive, Keratoacanthoma-type                             5
# Benign::Flat melanotic pigmentations - not melanocytic nevus::Lentigo NOS                                                                                             5
# Benign::Benign melanocytic proliferations::Nevus::Nevus, Congenital                                                                                                   4
# Benign::Benign melanocytic proliferations::Nevus::Nevus, Spitz                                                                                                        3
# Benign::Benign soft tissue proliferations - Vascular::Hemangioma::Hemangioma, Cherry                                                                                  3
# Benign::Benign epidermal proliferations::Pigmented benign keratosis                                                                                                   3
# Benign::Benign melanocytic proliferations::Nevus::Nevus, Of special anatomic site                                                                                     2
# Benign::Benign adnexal epithelial proliferations - Follicular                                                                                                         2
# Malignant::Malignant epidermal proliferations::Squamous cell carcinoma, NOS                                                                                           2
# Benign::Benign melanocytic proliferations::Nevus::Nevus, Combined                                                                                                     2
# Benign::Benign soft tissue proliferations - Fibro-histiocytic::Angiofibroma::Angiofibroma, Facial                                                                     2
# Benign::Benign melanocytic proliferations::Nevus::Nevus, Deep penetrating                                                                                             2
# Benign::Benign adnexal epithelial proliferations - Apocrine or Eccrine::Hidradenoma                                                                                   1
# Benign::Cysts                                                                                                                                                         1
# Benign::Benign soft tissue proliferations - Fibro-histiocytic::Fibroepithelial polyp                                                                                  1
# Malignant::Malignant melanocytic proliferations (Melanoma)::Melanoma Invasive::Melanoma Invasive, Nodular                                                             1
# Benign::Cysts::Trichilemmal or isthmic-catagen or pilar cyst                                                                                                          1
# Benign::Benign melanocytic proliferations::Nevus::Blue nevus::Blue nevus, Cellular                                                                                    1
# Malignant::Malignant epidermal proliferations::Squamous cell carcinoma in situ::Squamous cell carcinoma in situ, Bowens disease                                       1
# Malignant::Malignant melanocytic proliferations (Melanoma)::Melanoma metastasis                                                                                       1
# Benign::Benign soft tissue proliferations - Fibro-histiocytic::Scar                                                                                                   1
# Indeterminate::Indeterminate epidermal proliferations::Solar or actinic keratosis::Actinic keratosis, Bowenoid                                                        1
# Benign::Benign epidermal proliferations::Seborrheic keratosis::Seborrheic keratosis, Clonal                                                                           1
# Name: count, dtype: int64
# --------------------
# --------------------
# Statistics for column [target]
# count    401059.000000
# mean          0.000980
# std           0.031288
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: target, dtype: float64
# target
# 0    400666
# 1       393
# Name: count, dtype: int64
# --------------------
# --------------------
# Statistics for column [tbp_lv_A]
# count    401059.000000
# mean         19.974007
# std           3.999489
# min          -2.487115
# 25%          17.330821
# 50%          19.801910
# 75%          22.304628
# max          48.189610
# Name: tbp_lv_A, dtype: float64
# Number of nan: 0
# Unique values: 386052
# --------------------
# --------------------
# Statistics for column [tbp_lv_Aext]
# count    401059.000000
# mean         14.919247
# std           3.529384
# min          -9.080269
# 25%          12.469740
# 50%          14.713930
# 75%          17.137175
# max          37.021680
# Name: tbp_lv_Aext, dtype: float64
# Number of nan: 0
# Unique values: 385304
# --------------------
# --------------------
# Statistics for column [tbp_lv_B]
# count    401059.000000
# mean         28.281706
# std           5.278676
# min          -0.730989
# 25%          24.704372
# 50%          28.171570
# 75%          31.637429
# max          54.306900
# Name: tbp_lv_B, dtype: float64
# Number of nan: 0
# Unique values: 389890
# --------------------
# --------------------
# Statistics for column [tbp_lv_Bext]
# count    401059.000000
# mean         26.913015
# std           4.482994
# min           9.237066
# 25%          23.848125
# 50%          26.701704
# 75%          29.679913
# max          48.372700
# Name: tbp_lv_Bext, dtype: float64
# Number of nan: 0
# Unique values: 387763
# --------------------
# --------------------
# Statistics for column [tbp_lv_C]
# count    401059.000000
# mean         34.786341
# std           5.708469
# min           3.054228
# 25%          31.003148
# 50%          34.822580
# 75%          38.430298
# max          58.765170
# Name: tbp_lv_C, dtype: float64
# Number of nan: 0
# Unique values: 390703
# --------------------
# --------------------
# Statistics for column [tbp_lv_Cext]
# count    401059.000000
# mean         30.921279
# std           4.829345
# min          11.846520
# 25%          27.658285
# 50%          30.804893
# 75%          33.963868
# max          54.305290
# Name: tbp_lv_Cext, dtype: float64
# Number of nan: 0
# Unique values: 388865
# --------------------
# --------------------
# Statistics for column [tbp_lv_H]
# count    401059.000000
# mean         54.653689
# std           5.520849
# min          -1.574164
# 25%          51.566273
# 50%          55.035632
# 75%          58.298184
# max         105.875784
# Name: tbp_lv_H, dtype: float64
# Number of nan: 0
# Unique values: 389798
# --------------------
# --------------------
# Statistics for column [tbp_lv_Hext]
# count    401059.000000
# mean         60.996869
# std           5.631909
# min          28.436490
# 25%          57.297630
# 50%          61.109173
# 75%          64.905025
# max         130.983300
# Name: tbp_lv_Hext, dtype: float64
# Number of nan: 0
# Unique values: 390743
# --------------------
# --------------------
# Statistics for column [tbp_lv_L]
# count    401059.000000
# mean         42.289976
# std          10.864572
# min           4.223007
# 25%          34.303345
# 50%          42.343770
# 75%          50.405051
# max          87.548888
# Name: tbp_lv_L, dtype: float64
# Number of nan: 0
# Unique values: 395726
# --------------------
# --------------------
# Statistics for column [tbp_lv_Lext]
# count    401059.000000
# mean         51.199529
# std          12.100527
# min          17.702260
# 25%          42.274506
# 50%          51.425557
# 75%          60.495607
# max          98.588250
# Name: tbp_lv_Lext, dtype: float64
# Number of nan: 0
# Unique values: 396358
# --------------------
# --------------------
# Statistics for column [tbp_lv_areaMM2]
# count    401059.000000
# mean          8.539975
# std           9.679312
# min           0.431601
# 25%           4.109589
# 50%           5.685870
# 75%           9.119910
# max         334.152700
# Name: tbp_lv_areaMM2, dtype: float64
# Number of nan: 0
# Unique values: 8029
# --------------------
# --------------------
# Statistics for column [tbp_lv_area_perim_ratio]
# count    401059.000000
# mean         19.084517
# std           5.357863
# min          10.761634
# 25%          15.426205
# 50%          17.423950
# 75%          21.011340
# max          87.205340
# Name: tbp_lv_area_perim_ratio, dtype: float64
# Number of nan: 0
# Unique values: 167648
# --------------------
# --------------------
# Statistics for column [tbp_lv_color_std_mean]
# count    401059.000000
# mean          1.070408
# std           0.762918
# min           0.000000
# 25%           0.574909
# 50%           0.931402
# 75%           1.412154
# max           9.952932
# Name: tbp_lv_color_std_mean, dtype: float64
# Number of nan: 0
# Unique values: 371189
# --------------------
# --------------------
# Statistics for column [tbp_lv_deltaA]
# count    401059.000000
# mean          5.054760
# std           2.642928
# min         -13.819850
# 25%           3.413108
# 50%           4.643926
# 75%           6.274246
# max          32.137590
# Name: tbp_lv_deltaA, dtype: float64
# Number of nan: 0
# Unique values: 398257
# --------------------
# --------------------
# Statistics for column [tbp_lv_deltaB]
# count    401059.000000
# mean          1.368691
# std           2.215871
# min         -18.088106
# 25%           0.111030
# 50%           1.593945
# 75%           2.850638
# max          12.643930
# Name: tbp_lv_deltaB, dtype: float64
# Number of nan: 0
# Unique values: 398886
# --------------------
# --------------------
# Statistics for column [tbp_lv_deltaL]
# count    401059.000000
# mean         -8.909552
# std           3.463362
# min         -38.756140
# 25%         -10.675470
# 50%          -8.132223
# 75%          -6.397103
# max          -1.590631
# Name: tbp_lv_deltaL, dtype: float64
# Number of nan: 0
# Unique values: 396505
# --------------------
# --------------------
# Statistics for column [tbp_lv_deltaLB]
# count    401059.000000
# mean          9.455766
# std           3.466703
# min           2.952675
# 25%           6.952377
# 50%           8.699932
# 75%          11.243486
# max          39.197720
# Name: tbp_lv_deltaLB, dtype: float64
# Number of nan: 0
# Unique values: 395511
# --------------------
# --------------------
# Statistics for column [tbp_lv_deltaLBnorm]
# count    401059.000000
# mean          7.538922
# std           2.404951
# min           3.001138
# 25%           5.748160
# 50%           6.946320
# 75%           8.748403
# max          30.487456
# Name: tbp_lv_deltaLBnorm, dtype: float64
# Number of nan: 0
# Unique values: 396877
# --------------------
# --------------------
# Statistics for column [tbp_lv_dnn_lesion_confidence]
# count    4.010590e+05
# mean     9.716220e+01
# std      8.995782e+00
# min      1.261082e-16
# 25%      9.966882e+01
# 50%      9.999459e+01
# 75%      9.999996e+01
# max      1.000000e+02
# Name: tbp_lv_dnn_lesion_confidence, dtype: float64
# Number of nan: 0
# Unique values: 131480
# --------------------
# --------------------
# Statistics for column [tbp_lv_eccentricity]
# count    401059.000000
# mean          0.741238
# std           0.143857
# min           0.027667
# 25%           0.656627
# 50%           0.768215
# 75%           0.853175
# max           0.974960
# Name: tbp_lv_eccentricity, dtype: float64
# Number of nan: 0
# Unique values: 396648
# --------------------
# --------------------
# Statistics for column [tbp_lv_location]
# tbp_lv_location
# Torso Back Top Third       71112
# Torso Front Top Half       63350
# Torso Back Middle Third    46185
# Left Leg - Lower           27428
# Right Leg - Lower          25208
# Torso Front Bottom Half    24360
# Left Leg - Upper           23673
# Right Leg - Upper          23034
# Right Arm - Upper          22972
# Left Arm - Upper           22816
# Head & Neck                12046
# Left Arm - Lower           11939
# Right Arm - Lower          10636
# Unknown                     5756
# Torso Back Bottom Third     4596
# Left Leg                    1974
# Right Leg                   1711
# Left Arm                    1593
# Right Arm                    601
# Torso Front                   60
# Torso Back                     9
# Name: count, dtype: int64
# --------------------
# --------------------
# Statistics for column [tbp_lv_location_simple]
# tbp_lv_location_simple
# Torso Back     121902
# Torso Front     87770
# Left Leg        53075
# Right Leg       49953
# Left Arm        36348
# Right Arm       34209
# Head & Neck     12046
# Unknown          5756
# Name: count, dtype: int64
# --------------------
# --------------------
# Statistics for column [tbp_lv_minorAxisMM]
# count    401059.000000
# mean          2.539773
# std           1.173169
# min           0.273973
# 25%           1.812707
# 50%           2.265201
# 75%           2.905918
# max          18.387900
# Name: tbp_lv_minorAxisMM, dtype: float64
# Number of nan: 0
# Unique values: 75669
# --------------------
# --------------------
# Statistics for column [tbp_lv_nevi_confidence]
# count    401059.000000
# mean         38.520265
# std          41.480936
# min           0.000000
# 25%           0.109819
# 50%          14.408514
# 75%          87.791395
# max         100.000000
# Name: tbp_lv_nevi_confidence, dtype: float64
# Number of nan: 0
# Unique values: 395242
# --------------------
# --------------------
# Statistics for column [tbp_lv_norm_border]
# count    401059.000000
# mean          3.451523
# std           1.724557
# min           0.589426
# 25%           2.143836
# 50%           2.996933
# 75%           4.358399
# max          10.000000
# Name: tbp_lv_norm_border, dtype: float64
# Number of nan: 0
# Unique values: 391372
# --------------------
# --------------------
# Statistics for column [tbp_lv_norm_color]
# count    401059.000000
# mean          3.091590
# std           2.044813
# min           0.000000
# 25%           1.728774
# 50%           2.764664
# 75%           4.120246
# max          10.000000
# Name: tbp_lv_norm_color, dtype: float64
# Number of nan: 0
# Unique values: 368742
# --------------------
# --------------------
# Statistics for column [tbp_lv_perimeterMM]
# count    401059.000000
# mean         11.878891
# std           5.919302
# min           2.579237
# 25%           8.338364
# 50%          10.015440
# 75%          13.209100
# max         102.493900
# Name: tbp_lv_perimeterMM, dtype: float64
# Number of nan: 0
# Unique values: 9492
# --------------------
# --------------------
# Statistics for column [tbp_lv_radial_color_std_max]
# count    401059.000000
# mean          1.016459
# std           0.734631
# min           0.000000
# 25%           0.563891
# 50%           0.902281
# 75%           1.334523
# max          11.491140
# Name: tbp_lv_radial_color_std_max, dtype: float64
# Number of nan: 0
# Unique values: 367566
# --------------------
# --------------------
# Statistics for column [tbp_lv_stdL]
# count    401059.000000
# mean          2.715190
# std           1.738165
# min           0.268160
# 25%           1.456570
# 50%           2.186693
# 75%           3.474565
# max          17.563650
# Name: tbp_lv_stdL, dtype: float64
# Number of nan: 0
# Unique values: 396459
# --------------------
# --------------------
# Statistics for column [tbp_lv_stdLExt]
# count    401059.000000
# mean          2.238605
# std           0.623884
# min           0.636247
# 25%           1.834745
# 50%           2.149758
# 75%           2.531443
# max          25.534791
# Name: tbp_lv_stdLExt, dtype: float64
# Number of nan: 0
# Unique values: 390080
# --------------------
# --------------------
# Statistics for column [tbp_lv_symm_2axis]
# count    401059.000000
# mean          0.306823
# std           0.125038
# min           0.052034
# 25%           0.211429
# 50%           0.282297
# 75%           0.382022
# max           0.977055
# Name: tbp_lv_symm_2axis, dtype: float64
# Number of nan: 0
# Unique values: 74825
# --------------------
# --------------------
# Statistics for column [tbp_lv_symm_2axis_angle]
# count    401059.000000
# mean         86.332073
# std          52.559511
# min           0.000000
# 25%          40.000000
# 50%          90.000000
# 75%         130.000000
# max         175.000000
# Name: tbp_lv_symm_2axis_angle, dtype: float64
# Number of nan: 0
# Unique values: 36
# --------------------
# --------------------
# Statistics for column [tbp_lv_x]
# count    401059.000000
# mean         -3.091862
# std         197.257995
# min        -624.870728
# 25%        -147.022125
# 50%          -5.747253
# 75%         140.474835
# max         614.471700
# Name: tbp_lv_x, dtype: float64
# Number of nan: 0
# Unique values: 398446
# --------------------
# --------------------
# Statistics for column [tbp_lv_y]
# count    401059.000000
# mean       1039.598221
# std         409.819653
# min       -1052.134000
# 25%         746.519673
# 50%        1172.803000
# 75%        1342.131540
# max        1887.766846
# Name: tbp_lv_y, dtype: float64
# Number of nan: 0
# Unique values: 382410
# --------------------
# --------------------
# Statistics for column [tbp_lv_z]
# count    401059.000000
# mean         55.823389
# std          87.968245
# min        -291.890442
# 25%          -8.962647
# 50%          67.957947
# 75%         126.611567
# max         319.407000
# Name: tbp_lv_z, dtype: float64
# Number of nan: 0
# Unique values: 392817
# --------------------
# --------------------
# Statistics for column [tbp_tile_type]
# tbp_tile_type
# 3D: XP       285903
# 3D: white    115156
# Name: count, dtype: int64
# --------------------

# %%
printenc(
"""\
Compare iddx_3 with diagnosis column

Overlap in some major categories while others are harder to reconcile.

One can see some there seem to mean the same thing. It would also be able to
collapse down from subcategories (eg squamous cell carcinoma, * -> squamous cell carcinoma)\

IDDX_3 WILL BE MAPPED TO DIAGNOSIS WITH ISIC.MAP_IDDX3_DIAG()
NEW COLUMN DIAG_INFERRED WILL BE PRESENT TO INDICATE THIS
TODO: PLEASE REVIEW MAPPING!\
""")

lower_first_let = lambda s: s[0].lower() + s[1:]

iddx_3_keys = set([lower_first_let(s) 
                   for s in md24['iddx_3'].unique() if type(s) is str])
diag_keys = set(md_comp['diagnosis'].unique()) - set([np.nan])

def compare_diags():
    iddx_3_unique = sorted(iddx_3_keys - diag_keys)
    diag_unique = sorted(diag_keys - iddx_3_keys)
    diag_shared = sorted(diag_keys & iddx_3_keys)
    
    println("iddx_3 unique", iddx_3_unique, sep = '\n')
    println("diagnosis unique", diag_unique, sep = '\n')
    println("shared keys", diag_shared, sep = '\n')

printenc("Compare lowercased iddx_3 with diagnosis")
compare_diags()

# with this information we go on to produce a mapping.
# the function resides in isic.py for reuse later in processing.
iddx_3_keys = set([isic.map_iddx3_diag(key) for key in iddx_3_keys])

printenc("Map iddx_3 keys to diagnosis keys")
compare_diags()
# Out:
# --------------------
# Compare iddx_3 with diagnosis column
#
# Overlap in some major categories while others are harder to reconcile.
#
# One can see some there seem to mean the same thing. It would also be able to
# collapse down from subcategories (eg squamous cell carcinoma, * -> squamous cell carcinoma)
# IDDX_3 WILL BE MAPPED TO DIAGNOSIS WITH ISIC.MAP_IDDX3_DIAG()
# NEW COLUMN DIAG_INFERRED WILL BE PRESENT TO INDICATE THIS
# TODO: PLEASE REVIEW MAPPING!
# --------------------
# --------------------
# Compare lowercased iddx_3 with diagnosis
# --------------------
# iddx_3 unique
# ['angiofibroma', 'atypical intraepithelial melanocytic proliferation', 'atypical melanocytic neoplasm', 'fibroepithelial polyp', 'hemangioma', 'hidradenoma', 'lichen planus like keratosis', 'melanoma Invasive', 'melanoma in situ', 'melanoma, NOS', 'solar or actinic keratosis', 'squamous cell carcinoma in situ', 'squamous cell carcinoma, Invasive', 'squamous cell carcinoma, NOS', 'trichilemmal or isthmic-catagen or pilar cyst']
#
# diagnosis unique
# ['AIMP', 'acrochordon', 'actinic keratosis', 'angiofibroma or fibrous papule', 'angiokeratoma', 'angioma', 'atypical melanocytic proliferation', 'atypical spitz tumor', 'cafe-au-lait macule', 'clear cell acanthoma', 'lentigo simplex', 'lichenoid keratosis', 'melanoma', 'mucosal melanosis', 'neurofibroma', 'nevus spilus', 'other', 'pyogenic granuloma', 'sebaceous adenoma', 'sebaceous hyperplasia', 'squamous cell carcinoma', 'vascular lesion']
#
# shared keys
# ['basal cell carcinoma', 'dermatofibroma', 'lentigo NOS', 'melanoma metastasis', 'nevus', 'pigmented benign keratosis', 'scar', 'seborrheic keratosis', 'solar lentigo', 'verruca']
#
# --------------------
# Map iddx_3 keys to diagnosis keys
# --------------------
# iddx_3 unique
# []
#
# diagnosis unique
# ['angiokeratoma', 'atypical spitz tumor', 'cafe-au-lait macule', 'clear cell acanthoma', 'lentigo simplex', 'mucosal melanosis', 'neurofibroma', 'nevus spilus', 'pyogenic granuloma', 'sebaceous adenoma', 'sebaceous hyperplasia', 'vascular lesion']
#
# shared keys
# ['AIMP', 'acrochordon', 'actinic keratosis', 'angiofibroma or fibrous papule', 'angioma', 'atypical melanocytic proliferation', 'basal cell carcinoma', 'dermatofibroma', 'lentigo NOS', 'lichenoid keratosis', 'melanoma', 'melanoma metastasis', 'nevus', 'other', 'pigmented benign keratosis', 'scar', 'seborrheic keratosis', 'solar lentigo', 'squamous cell carcinoma', 'verruca']

# %%
printenc(
"""\
Study statistics shared columns between 2024 and archive.

Values are checked to make sure the naming of the labels are CONSISTENT between 2024 and complete sets.

Now in this list there are a few PARAMETERS THAT ARE MORE USEFUL since they benefit
from the much larger number of positive cases in the isic archive set.
Although one will have to consider how to deal with NAN VALUES in eg sex.

There are also a few parameters that have mostly nan values (see end of each block!)

A ROUGH SUGGESTION: age_approx, anatom_site_general, clin_size_long_diam_mm, sex\
"""
)

for col in sorted(col_shared):
    printdash()
    println(f"Statistics for column [{col}]")
    print("[2024]")
    println(isic.dtype_based_stats(md24, col))
    print("[complete]")
    print(isic.dtype_based_stats(md_comp, col))
    printdash()
# Out:
# --------------------
# Study statistics shared columns between 2024 and archive.
#
# Values are checked to make sure the naming of the labels are CONSISTENT between 2024 and complete sets.
#
# Now in this list there are a few PARAMETERS THAT ARE MORE USEFUL since they benefit
# from the much larger number of positive cases in the isic archive set.
# Although one will have to consider how to deal with NAN VALUES in eg sex.
#
# There are also a few parameters that have mostly nan values (see end of each block!)
#
# A ROUGH SUGGESTION: age_approx, anatom_site_general, clin_size_long_diam_mm, sex
# --------------------
# --------------------
# Statistics for column [PROC_source]
#
# [2024]
# PROC_source
# 2024    401059
# Name: count, dtype: int64
#
# [complete]
# PROC_source
# complete    81722
# Name: count, dtype: int64
# --------------------
# --------------------
# Statistics for column [PROC_use]
#
# [2024]
# PROC_use
# training    401059
# Name: count, dtype: int64
#
# [complete]
# PROC_use
#     81722
# Name: count, dtype: int64
# --------------------
# --------------------
# Statistics for column [age_approx]
#
# [2024]
# count    398261.000000
# mean         58.012986
# std          13.596165
# min           5.000000
# 25%          50.000000
# 50%          60.000000
# 75%          70.000000
# max          85.000000
# Name: age_approx, dtype: float64
# Number of nan: 2798
# Unique values: 17
#
# [complete]
# count    79702.000000
# mean        47.849489
# std         19.865311
# min          0.000000
# 25%         35.000000
# 50%         50.000000
# 75%         65.000000
# max         85.000000
# Name: age_approx, dtype: float64
# Number of nan: 2020
# Unique values: 19
# --------------------
# --------------------
# Statistics for column [anatom_site_general]
#
# [2024]
# anatom_site_general
# posterior torso    121902
# lower extremity    103028
# anterior torso      87770
# upper extremity     70557
# head/neck           12046
# NaN                  5756
# Name: count, dtype: int64
#
# [complete]
# anatom_site_general
# NaN                16979
# lower extremity    16173
# anterior torso     13999
# posterior torso    13639
# upper extremity    10053
# head/neck           8800
# lateral torso       1036
# palms/soles          845
# oral/genital         198
# Name: count, dtype: int64
# --------------------
# --------------------
# Statistics for column [attribution]
#
# [2024]
# attribution
# Memorial Sloan Kettering Cancer Center                                                                                                                 129068
# Department of Dermatology, Hospital Clínic de Barcelona                                                                                                105724
# University Hospital of Basel                                                                                                                            65218
# Frazer Institute, The University of Queensland, Dermatology Research Centre                                                                             51768
# ACEMID MIA                                                                                                                                              28665
# ViDIR Group, Department of Dermatology, Medical University of Vienna                                                                                    12640
# Department of Dermatology, University of Athens, Andreas Syggros Hospital of Skin and Venereal Diseases, Alexander Stratigos, Konstantinos Liopyris      7976
# Name: count, dtype: int64
#
# [complete]
# attribution
# Anonymous                                                                                                       19640
# ViDIR Group, Department of Dermatology, Medical University of Vienna                                            16094
# Memorial Sloan Kettering Cancer Center                                                                          13147
# Hospital Clínic de Barcelona                                                                                    12413
# The University of Queensland Diamantina Institute, The University of Queensland, Dermatology Research Centre     8449
# Department of Dermatology, Hospital Clínic de Barcelona                                                          7311
# Sydney Melanoma Diagnostic Center at Royal Prince Alfred Hospital, Pascale Guitera                               1884
# Hospital Italiano de Buenos Aires                                                                                1635
# "Repeated dermoscopic images of melanocytic lesions" by University Hospital Basel / CC-BY-NC                      585
# Department of Dermatology, Medical University of Vienna                                                           328
# Sydney Melanoma Diagnostic Center at Royal Prince Alfred Hospital                                                 187
# University of Pittsburgh Medical Center and Hillman Cancer Center                                                  36
# Dr. Julien Anriot                                                                                                   7
# Dermoscopedia                                                                                                       5
# Konstantinos Liopyris                                                                                               1
# Name: count, dtype: int64
# --------------------
# --------------------
# Statistics for column [clin_size_long_diam_mm]
#
# [2024]
# count    401059.000000
# mean          3.930827
# std           1.743068
# min           1.000000
# 25%           2.840000
# 50%           3.370000
# 75%           4.380000
# max          28.400000
# Name: clin_size_long_diam_mm, dtype: float64
# Number of nan: 0
# Unique values: 1758
#
# [complete]
# count    4003.00000
# mean        6.65271
# std         4.70387
# min         0.80000
# 25%         4.00000
# 50%         5.70000
# 75%         8.00000
# max       100.00000
# Name: clin_size_long_diam_mm, dtype: float64
# Number of nan: 77719
# Unique values: 194
# --------------------
# --------------------
# Statistics for column [copyright_license]
#
# [2024]
# copyright_license
# CC-BY       188812
# CC-BY-NC    183582
# CC-0         28665
# Name: count, dtype: int64
#
# [complete]
# copyright_license
# CC-BY-NC    49723
# CC-0        20086
# CC-BY       11913
# Name: count, dtype: int64
# --------------------
# --------------------
# Statistics for column [image_type]
#
# [2024]
# image_type
# TBP tile: close-up    401059
# Name: count, dtype: int64
#
# [complete]
# image_type
# dermoscopic           81155
# clinical: overview      432
# clinical: close-up       98
# TBP tile: overview       36
# NaN                       1
# Name: count, dtype: int64
# --------------------
# --------------------
# Statistics for column [isic_id]
#
# [2024]
# isic_id
# ISIC_0015670    1
# ISIC_6699080    1
# ISIC_6699647    1
# ISIC_6699636    1
# ISIC_6699544    1
#                ..
# ISIC_3386076    1
# ISIC_3386019    1
# ISIC_3386003    1
# ISIC_3385996    1
# ISIC_9999967    1
# Name: count, Length: 401059, dtype: int64
#
# [complete]
# isic_id
# ISIC_7559201    1
# ISIC_0032034    1
# ISIC_0032027    1
# ISIC_0032028    1
# ISIC_0032029    1
#                ..
# ISIC_9573024    1
# ISIC_6189075    1
# ISIC_1578811    1
# ISIC_0901403    1
# ISIC_0000000    1
# Name: count, Length: 81722, dtype: int64
# --------------------
# --------------------
# Statistics for column [lesion_id]
#
# [2024]
# lesion_id
# NaN           379001
# IL_3147105         1
# IL_0180339         1
# IL_7214852         1
# IL_0805062         1
#                ...
# IL_7607592         1
# IL_0002671         1
# IL_2549391         1
# IL_7938193         1
# IL_9852274         1
# Name: count, Length: 22059, dtype: int64
#
# [complete]
# lesion_id
# NaN           17756
# IL_5161836       31
# IL_4163485       27
# IL_9292662       26
# IL_3937356       24
#               ...
# IL_2599644        1
# IL_6514359        1
# IL_6986695        1
# IL_1677744        1
# IL_0134474        1
# Name: count, Length: 50079, dtype: int64
# --------------------
# --------------------
# Statistics for column [mel_mitotic_index]
#
# [2024]
# mel_mitotic_index
# <NA>       401006
# 0/mm^2         22
# <1/mm^2        19
# >4/mm^2         4
# 1/mm^2          3
# 3/mm^2          2
# 2/mm^2          2
# 4/mm^2          1
# Name: count, dtype: Int64
#
# [complete]
# mel_mitotic_index
# <NA>       81667
# 0/mm^2        24
# 1/mm^2         9
# <1/mm^2        9
# 2/mm^2         7
# 4/mm^2         3
# >4/mm^2        2
# 3/mm^2         1
# Name: count, dtype: Int64
# --------------------
# --------------------
# Statistics for column [mel_thick_mm]
#
# [2024]
# count    63.000000
# mean      0.670952
# std       0.792798
# min       0.200000
# 25%       0.300000
# 50%       0.400000
# 75%       0.600000
# max       5.000000
# Name: mel_thick_mm, dtype: float64
# Number of nan: 400996
# Unique values: 20
#
# [complete]
# count    739.000000
# mean       0.463464
# std        1.199795
# min        0.000000
# 25%        0.000000
# 50%        0.190000
# 75%        0.445000
# max       24.000000
# Name: mel_thick_mm, dtype: float64
# Number of nan: 80983
# Unique values: 62
# --------------------
# --------------------
# Statistics for column [patient_id]
#
# [2024]
# patient_id
# IP_1117889    9184
# IP_5714646    6267
# IP_3921915    5568
# IP_7797815    4454
# IP_9577633    3583
#               ...
# IP_5792391       1
# IP_1216329       1
# IP_4004571       1
# IP_1487179       1
# IP_7696347       1
# Name: count, Length: 1042, dtype: int64
#
# [complete]
# patient_id
# NaN           40594
# IP_4938382      117
# IP_7279968      115
# IP_4479736      115
# IP_4382720      115
#               ...
# IP_2677654        1
# IP_2273278        1
# IP_8439095        1
# IP_0549014        1
# IP_6191697        1
# Name: count, Length: 5349, dtype: int64
# --------------------
# --------------------
# Statistics for column [sex]
#
# [2024]
# sex
# male      265546
# female    123996
# NaN        11517
# Name: count, dtype: int64
#
# [complete]
# sex
# male      43015
# female    36798
# NaN        1909
# Name: count, dtype: int64
# --------------------

# %%
printenc(
"""\
Study the named diagnoses in iddx_3

By looking at their statistics we confirm our previous guesses for
assignment to benign_malignant in the benign_malignant = nan cases in
the complete set.\
"""
)

# there can be statistics in nan diagnosis but we cannot make any logical deductions
# from a null-diagnosis, even if we have the statistics.
iddx_3_keys = set(md24['iddx_3'].unique()) - set([np.nan])

for key in sorted(iddx_3_keys):
    diag = isic.map_iddx3_diag(key)
    # as noted before iddx_3 = diagnosis, iddx_1 = benign_malignant
    # diag is the key as represented in the original isic archives
    printenc(f'[{key}] mapping to diagnosis [{diag}]',
             md24[md24['iddx_3'] == key]['iddx_1'].value_counts(dropna=False),
             '',
             md_comp[md_comp['diagnosis'] == diag]['benign_malignant'].value_counts(dropna=False))
# Out:
# --------------------
# Study the named diagnoses in iddx_3
#
# By looking at their statistics we confirm our previous guesses for
# assignment to benign_malignant in the benign_malignant = nan cases in
# the complete set.
# --------------------
# --------------------
# [Angiofibroma] mapping to diagnosis [angiofibroma or fibrous papule]
# iddx_1
# Benign    2
# Name: count, dtype: int64
#
# benign_malignant
# benign    4
# Name: count, dtype: int64
# --------------------
# --------------------
# [Atypical intraepithelial melanocytic proliferation] mapping to diagnosis [AIMP]
# iddx_1
# Indeterminate    11
# Name: count, dtype: int64
#
# benign_malignant
# indeterminate              61
# indeterminate/malignant    44
# indeterminate/benign       14
# benign                      2
# Name: count, dtype: int64
# --------------------
# --------------------
# [Atypical melanocytic neoplasm] mapping to diagnosis [atypical melanocytic proliferation]
# iddx_1
# Indeterminate    64
# Name: count, dtype: int64
#
# benign_malignant
# indeterminate              60
# indeterminate/benign       40
# benign                     29
# indeterminate/malignant    14
# Name: count, dtype: int64
# --------------------
# --------------------
# [Basal cell carcinoma] mapping to diagnosis [basal cell carcinoma]
# iddx_1
# Malignant    163
# Name: count, dtype: int64
#
# benign_malignant
# NaN          3436
# malignant    1165
# benign        320
# Name: count, dtype: int64
# --------------------
# --------------------
# [Dermatofibroma] mapping to diagnosis [dermatofibroma]
# iddx_1
# Benign    11
# Name: count, dtype: int64
#
# benign_malignant
# NaN       284
# benign    136
# Name: count, dtype: int64
# --------------------
# --------------------
# [Fibroepithelial polyp] mapping to diagnosis [acrochordon]
# iddx_1
# Benign    1
# Name: count, dtype: int64
#
# benign_malignant
# benign    301
# Name: count, dtype: int64
# --------------------
# --------------------
# [Hemangioma] mapping to diagnosis [angioma]
# iddx_1
# Benign    3
# Name: count, dtype: int64
#
# benign_malignant
# benign    71
# Name: count, dtype: int64
# --------------------
# --------------------
# [Hidradenoma] mapping to diagnosis [other]
# iddx_1
# Benign    1
# Name: count, dtype: int64
#
# benign_malignant
# benign       32
# malignant     1
# Name: count, dtype: int64
# --------------------
# --------------------
# [Lentigo NOS] mapping to diagnosis [lentigo NOS]
# iddx_1
# Benign    5
# Name: count, dtype: int64
#
# benign_malignant
# benign                  240
# indeterminate/benign      1
# Name: count, dtype: int64
# --------------------
# --------------------
# [Lichen planus like keratosis] mapping to diagnosis [lichenoid keratosis]
# iddx_1
# Benign    11
# Name: count, dtype: int64
#
# benign_malignant
# benign    312
# Name: count, dtype: int64
# --------------------
# --------------------
# [Melanoma Invasive] mapping to diagnosis [melanoma]
# iddx_1
# Malignant    63
# Name: count, dtype: int64
#
# benign_malignant
# malignant                  7320
# indeterminate/malignant      22
# NaN                           7
# Name: count, dtype: int64
# --------------------
# --------------------
# [Melanoma in situ] mapping to diagnosis [melanoma]
# iddx_1
# Malignant    80
# Name: count, dtype: int64
#
# benign_malignant
# malignant                  7320
# indeterminate/malignant      22
# NaN                           7
# Name: count, dtype: int64
# --------------------
# --------------------
# [Melanoma metastasis] mapping to diagnosis [melanoma metastasis]
# iddx_1
# Malignant    1
# Name: count, dtype: int64
#
# benign_malignant
# malignant    38
# benign        1
# Name: count, dtype: int64
# --------------------
# --------------------
# [Melanoma, NOS] mapping to diagnosis [melanoma]
# iddx_1
# Malignant    13
# Name: count, dtype: int64
#
# benign_malignant
# malignant                  7320
# indeterminate/malignant      22
# NaN                           7
# Name: count, dtype: int64
# --------------------
# --------------------
# [Nevus] mapping to diagnosis [nevus]
# iddx_1
# Benign    443
# Name: count, dtype: int64
#
# benign_malignant
# benign                  32670
# indeterminate              15
# indeterminate/benign       12
# Name: count, dtype: int64
# --------------------
# --------------------
# [Pigmented benign keratosis] mapping to diagnosis [pigmented benign keratosis]
# iddx_1
# Benign    3
# Name: count, dtype: int64
#
# benign_malignant
# NaN       1338
# benign       1
# Name: count, dtype: int64
# --------------------
# --------------------
# [Scar] mapping to diagnosis [scar]
# iddx_1
# Benign    1
# Name: count, dtype: int64
#
# benign_malignant
# benign                     26
# indeterminate/malignant     5
# Name: count, dtype: int64
# --------------------
# --------------------
# [Seborrheic keratosis] mapping to diagnosis [seborrheic keratosis]
# iddx_1
# Benign    57
# Name: count, dtype: int64
#
# benign_malignant
# benign       984
# NaN          929
# malignant     13
# Name: count, dtype: int64
# --------------------
# --------------------
# [Solar lentigo] mapping to diagnosis [solar lentigo]
# iddx_1
# Benign    12
# Name: count, dtype: int64
#
# benign_malignant
# benign    353
# NaN       209
# Name: count, dtype: int64
# --------------------
# --------------------
# [Solar or actinic keratosis] mapping to diagnosis [actinic keratosis]
# iddx_1
# Indeterminate    39
# Name: count, dtype: int64
#
# benign_malignant
# NaN              886
# benign           478
# indeterminate      3
# Name: count, dtype: int64
# --------------------
# --------------------
# [Squamous cell carcinoma in situ] mapping to diagnosis [squamous cell carcinoma]
# iddx_1
# Malignant    49
# Name: count, dtype: int64
#
# benign_malignant
# NaN          667
# malignant    653
# benign        52
# Name: count, dtype: int64
# --------------------
# --------------------
# [Squamous cell carcinoma, Invasive] mapping to diagnosis [squamous cell carcinoma]
# iddx_1
# Malignant    22
# Name: count, dtype: int64
#
# benign_malignant
# NaN          667
# malignant    653
# benign        52
# Name: count, dtype: int64
# --------------------
# --------------------
# [Squamous cell carcinoma, NOS] mapping to diagnosis [squamous cell carcinoma]
# iddx_1
# Malignant    2
# Name: count, dtype: int64
#
# benign_malignant
# NaN          667
# malignant    653
# benign        52
# Name: count, dtype: int64
# --------------------
# --------------------
# [Trichilemmal or isthmic-catagen or pilar cyst] mapping to diagnosis [other]
# iddx_1
# Benign    1
# Name: count, dtype: int64
#
# benign_malignant
# benign       32
# malignant     1
# Name: count, dtype: int64
# --------------------
# --------------------
# [Verruca] mapping to diagnosis [verruca]
# iddx_1
# Benign    7
# Name: count, dtype: int64
#
# benign_malignant
# benign    119
# Name: count, dtype: int64
# --------------------
